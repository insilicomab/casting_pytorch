# %%
# !pip install signate

from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth


auth.authenticate_user()

drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'signate.json'", fields="files(id)").execute()
signate_api_key = results.get('files', [])

filename = "/root/.signate/signate.json"
os.makedirs(os.path.dirname(filename), exist_ok=True)

request = drive_service.files().get_media(fileId=signate_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)
# Out:
# Collecting signate
#   Downloading signate-0.9.9-py3-none-any.whl (37 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from signate) (0.8.9)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from signate) (2021.10.8)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from signate) (2.8.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from signate) (7.1.2)
# Collecting urllib3>=1.26.7
#   Downloading urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 8.8 MB/s
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Collecting six>=1.16
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=90c9274e11fe2ee60937214113b046a6d9dea8d25abe6b16b5375d17334c81aa
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: six, wget, urllib3, signate
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.8 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed signate-0.9.9 six-1.16.0 urllib3-1.26.8 wget-3.2
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Download 100%.

# %%
! signate list 
! signate files --competition-id=406
! signate download --competition-id=406
# Out:
#   competitionId  title                                                                                      closing     prize                  submitters
# ---------------  -----------------------------------------------------------------------------------------  ----------  -------------------  ------------
#               1  【練習問題】銀行の顧客ターゲティング                                                       -                                        5396
#              24  【練習問題】お弁当の需要予測                                                               -                                        6663
#              27  【練習問題】Jリーグの観客動員数予測                                                        -                                        1527
#             100  【練習問題】手書き文字認識                                                                 -           Knowledge                     204
#             102  【練習問題】タイタニックの生存予測                                                         -           Knowledge                    1259
#             103  【練習問題】音楽ラベリング                                                                 -           Knowledge                      62
#             104  【練習問題】スパムメール分類                                                               -           Knowledge                     135
#             105  【練習問題】毒キノコの分類                                                                 -           Knowledge                     267
#             106  【練習問題】アワビの年齢予測                                                               -           Knowledge                     363
#             107  【練習問題】国勢調査からの収入予測                                                         -           Knowledge                     543
#             108  【練習問題】画像ラベリング（20種類）                                                       -           Knowledge                     226
#             112  【練習問題】ワインの品種の予測                                                             -           Knowledge                     314
#             113  【練習問題】山火事の消失面積予測                                                           -           Knowledge                     203
#             114  【練習問題】レンタル自転車の利用者数予測                                                   -           Knowledge                     385
#             115  【練習問題】アヤメの分類                                                                   -           Knowledge                     355
#             116  【練習問題】活動センサーログからの動作予測                                                 -           Knowledge                      50
#             118  【練習問題】テニスの試合結果の予測                                                         -           Knowledge                     124
#             121  【練習問題】自動車の走行距離予測                                                           -           Knowledge                    1461
#             122  【練習問題】自動車の評価                                                                   -           Knowledge                     315
#             123  【練習問題】オゾンレベルの分類                                                             -           Knowledge                      45
#             124  【練習問題】ボットの判別                                                                   -           Knowledge                     303
#             125  【練習問題】ガラスの分類                                                                   -           Knowledge                     155
#             126  【練習問題】林型の分類                                                                     -           Knowledge                      39
#             127  【練習問題】ゲーム選手のリーグ分類                                                         -           Knowledge                      57
#             128  【練習問題】ステンレス板の欠陥分類                                                         -           Knowledge                      64
#             129  【練習問題】都市サイクルの燃料消費量予測                                                   -           Knowledge                     123
#             130  【練習問題】天秤のバランス分類                                                             -           Knowledge                      98
#             132  【練習問題】ネット広告のクリック予測                                                       -           Knowledge                     143
#             133  【練習問題】画像ラベリング（10種類）                                                       -                                         348
#             135  【練習問題】ネット画像の分類                                                               -                                          74
#             262  【SOTA】国立国会図書館の画像データレイアウト認識                                           2100-12-31  -                              72
#             263  【SOTA】産業技術総合研究所 衛星画像分析コンテスト                                          2100-12-31  -                              44
#             264  【SOTA】マイナビ × SIGNATE Student Cup 2019: 賃貸物件の家賃予測                            2100-12-31  -                             366
#             265  【練習問題】健診データによる肝疾患判定                                                     -                                         507
#             266  【練習問題】民泊サービスの宿泊価格予測                                                     -                                         573
#             267  【SOTA】海洋研究開発機構 熱帯低気圧（台風等）検出アルゴリズム作成                          2100-12-31  -                              17
#             268  【SOTA】オプト レコメンドエンジン作成                                                      2100-12-31                                 34
#             269  【SOTA】アップル 引越し需要予測                                                            2100-12-31  -                             326
#             270  【SOTA】Weather Challenge：雲画像予測                                                      2100-12-31  -                               7
#             271  【SOTA】JR西日本 走行中の北陸新幹線車両台車部の着雪量予測                                  2100-12-31  -                              20
#             288  【SOTA】Sansan 名刺の項目予測                                                              2100-12-31  -                              30
#             294  【練習問題】債務不履行リスクの低減                                                         -                                         189
#             358  【練習問題】機械稼働音の異常検知                                                           -                                          72
#             404  【練習問題】モノクロ顔画像の感情分類                                                       -                                          76
#             406  【練習問題】鋳造製品の欠陥検出                                                             -                                         188
#             409  【練習問題】株価の推移予測                                                                 -                                         174
#             489  【AIQuest2021】PBL_01 需要予測・在庫最適化（小売業）ビジネス導入課題①                      2022-02-05                                521
#             490  【AIQuest2021】PBL_01 需要予測・在庫最適化（小売業）ビジネス導入課題②                      2022-02-05                                518
#             491  【AIQuest2021】PBL_01 需要予測・在庫最適化（小売業）ビジネス導入課題③                      2022-02-05                                517
#             492  【AIQuest2021】PBL_01 需要予測・在庫最適化（小売業）AI課題                                 2022-02-05                                482
#             493  【AIQuest2021】PBL_01 需要予測・在庫最適化（小売業）ビジネス実装課題                       2022-02-05                                369
#             517  【AIQuest2021】PBL_05 不良個所自動検出による検品作業効率化（木材加工業）ビジネス導入課題①  2022-02-05                                149
#             518  【AIQuest2021】PBL_05 不良個所自動検出による検品作業効率化（木材加工業）ビジネス導入課題②  2022-02-05                                149
#             519  【AIQuest2021】PBL_05 不良個所自動検出による検品作業効率化（木材加工業）ビジネス導入課題③  2022-02-05                                149
#             520  【AIQuest2021】PBL_05 不良個所自動検出による検品作業効率化（木材加工業）AI課題             2022-02-05                                134
#             521  【AIQuest2021】PBL_05 不良個所自動検出による検品作業効率化（木材加工業）ビジネス実装課題   2022-02-05                                 94
#             537  第5回AIエッジコンテスト（実装コンテスト③）                                                 2022-02-15  total 1,600,000 yen            12
#             563  SUBARU 画像認識チャレンジ                                                                  2022-01-31  総額¥2,000,000                107
#             565  【SOTA】SIGNATE Student Cup 2021春：楽曲のジャンル推定チャレンジ！！                       2100-12-31  -                              26
#             567  【SOTA】SIGNATE Student Cup 2021秋：オペレーション最適化に向けたシェアサイクルの利用予測   2100-12-31  -                              20
#   fileId  name                   title                                size  updated_at
# --------  ---------------------  --------------------------------  -------  -------------------
#     1536  train_data.zip         学習用画像データ                  2533668  2020-12-04 18:06:22
#     1537  test_data.zip          評価用画像データ                  1006514  2020-12-04 18:07:43
#     1538  train.csv              学習用画像データとラベルの対応表     5415  2020-12-04 18:08:30
#     1539  sample_submission.csv  応募用サンプルファイル               1392  2020-12-04 18:08:53
# sample_submission.csv
#
# train.csv
#
# test_data.zip
#
# train_data.zip
#
#
# Download completed.

# %%
! unzip train_data.zip
# Out:
# Archive:  train_data.zip
#    creating: train_data/
#   inflating: train_data/cast_def_0_335.jpeg
#    creating: __MACOSX/
#    creating: __MACOSX/train_data/
#   inflating: __MACOSX/train_data/._cast_def_0_335.jpeg
#   inflating: train_data/cast_ok_0_369.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_369.jpeg
#   inflating: train_data/cast_ok_0_294.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_294.jpeg
#   inflating: train_data/cast_ok_0_152.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_152.jpeg
#   inflating: train_data/cast_def_0_323.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_323.jpeg
#   inflating: train_data/cast_def_0_2378.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2378.jpeg
#   inflating: train_data/cast_ok_0_345.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_345.jpeg
#   inflating: train_data/cast_def_0_2401.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2401.jpeg
#   inflating: train_data/cast_def_0_61.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_61.jpeg
#   inflating: train_data/cast_def_0_163.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_163.jpeg
#   inflating: train_data/cast_ok_0_191.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_191.jpeg
#   inflating: train_data/cast_def_0_175.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_175.jpeg
#   inflating: train_data/cast_def_0_2505.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2505.jpeg
#   inflating: train_data/cast_def_0_319.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_319.jpeg
#   inflating: train_data/cast_def_0_2381.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2381.jpeg
#   inflating: train_data/cast_def_0_122.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_122.jpeg
#   inflating: train_data/cast_def_0_98.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_98.jpeg
#   inflating: train_data/cast_def_0_339.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_339.jpeg
#   inflating: train_data/cast_def_0_2460.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2460.jpeg
#   inflating: train_data/cast_def_0_2437.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2437.jpeg
#   inflating: train_data/cast_def_0_0.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_0.jpeg
#   inflating: train_data/cast_def_0_41.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_41.jpeg
#   inflating: train_data/cast_ok_0_220.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_220.jpeg
#   inflating: train_data/cast_def_0_2499.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2499.jpeg
#   inflating: train_data/cast_ok_0_298.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_298.jpeg
#   inflating: train_data/cast_ok_0_430.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_430.jpeg
#   inflating: train_data/cast_def_0_211.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_211.jpeg
#   inflating: train_data/cast_def_0_354.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_354.jpeg
#   inflating: train_data/cast_def_0_82.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_82.jpeg
#   inflating: train_data/cast_ok_0_349.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_349.jpeg
#   inflating: train_data/cast_ok_0_467.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_467.jpeg
#   inflating: train_data/cast_def_0_315.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_315.jpeg
#   inflating: train_data/cast_def_0_196.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_196.jpeg
#   inflating: train_data/cast_def_0_207.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_207.jpeg
#   inflating: train_data/cast_ok_0_426.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_426.jpeg
#   inflating: train_data/cast_ok_0_427.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_427.jpeg
#   inflating: train_data/cast_def_0_95.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_95.jpeg
#   inflating: train_data/cast_def_0_197.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_197.jpeg
#   inflating: train_data/cast_def_0_314.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_314.jpeg
#   inflating: train_data/cast_ok_0_466.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_466.jpeg
#   inflating: train_data/cast_def_0_355.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_355.jpeg
#   inflating: train_data/cast_ok_0_364.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_364.jpeg
#   inflating: train_data/cast_def_0_40.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_40.jpeg
#   inflating: train_data/cast_def_0_103.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_103.jpeg
#   inflating: train_data/cast_def_0_56.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_56.jpeg
#   inflating: train_data/cast_ok_0_149.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_149.jpeg
#   inflating: train_data/cast_def_0_99.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_99.jpeg
#   inflating: train_data/cast_def_0_2441.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2441.jpeg
#   inflating: train_data/cast_def_0_21.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_21.jpeg
#   inflating: train_data/cast_ok_0_186.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_186.jpeg
#   inflating: train_data/cast_ok_0_169.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_169.jpeg
#   inflating: train_data/cast_def_0_2504.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2504.jpeg
#   inflating: train_data/cast_def_0_2457.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2457.jpeg
#   inflating: train_data/cast_ok_0_313.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_313.jpeg
#   inflating: train_data/cast_def_0_2400.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2400.jpeg
#   inflating: train_data/cast_def_0_60.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_60.jpeg
#   inflating: train_data/cast_def_0_359.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_359.jpeg
#   inflating: train_data/cast_def_0_135.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_135.jpeg
#   inflating: train_data/cast_ok_0_153.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_153.jpeg
#   inflating: train_data/cast_ok_0_411.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_411.jpeg
#   inflating: train_data/cast_def_0_363.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_363.jpeg
#   inflating: train_data/cast_ok_0_407.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_407.jpeg
#   inflating: train_data/cast_def_0_2482.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2482.jpeg
#   inflating: train_data/cast_ok_0_450.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_450.jpeg
#   inflating: train_data/cast_def_0_2523.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2523.jpeg
#   inflating: train_data/cast_def_0_2489.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2489.jpeg
#   inflating: train_data/cast_ok_0_322.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_322.jpeg
#   inflating: train_data/cast_def_0_2431.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2431.jpeg
#   inflating: train_data/cast_def_0_51.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_51.jpeg
#   inflating: train_data/cast_def_0_2470.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2470.jpeg
#   inflating: train_data/cast_ok_0_271.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_271.jpeg
#   inflating: train_data/cast_ok_0_461.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_461.jpeg
#   inflating: train_data/cast_def_0_2519.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2519.jpeg
#   inflating: train_data/cast_def_0_186.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_186.jpeg
#   inflating: train_data/cast_def_0_313.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_313.jpeg
#   inflating: train_data/cast_ok_0_420.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_420.jpeg
#   inflating: train_data/cast_def_0_92.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_92.jpeg
#   inflating: train_data/cast_ok_0_284.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_284.jpeg
#   inflating: train_data/cast_def_0_333.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_333.jpeg
#   inflating: train_data/cast_ok_0_379.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_379.jpeg
#   inflating: train_data/cast_def_0_372.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_372.jpeg
#   inflating: train_data/cast_ok_0_154.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_154.jpeg
#   inflating: train_data/cast_def_0_2391.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2391.jpeg
#   inflating: train_data/cast_def_0_2407.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2407.jpeg
#   inflating: train_data/cast_def_0_88.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_88.jpeg
#   inflating: train_data/cast_ok_0_302.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_302.jpeg
#   inflating: train_data/cast_def_0_26.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_26.jpeg
#   inflating: train_data/cast_ok_0_355.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_355.jpeg
#   inflating: train_data/cast_def_0_2411.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2411.jpeg
#   inflating: train_data/cast_def_0_348.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_348.jpeg
#   inflating: train_data/cast_def_0_70.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_70.jpeg
#   inflating: train_data/cast_ok_0_211.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_211.jpeg
#   inflating: train_data/cast_def_0_27.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_27.jpeg
#   inflating: train_data/cast_def_0_31.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_31.jpeg
#   inflating: train_data/cast_ok_0_196.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_196.jpeg
#   inflating: train_data/cast_def_0_308.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_308.jpeg
#   inflating: train_data/cast_ok_0_250.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_250.jpeg
#   inflating: train_data/cast_def_0_66.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_66.jpeg
#   inflating: train_data/cast_def_0_89.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_89.jpeg
#   inflating: train_data/cast_def_0_2390.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2390.jpeg
#   inflating: train_data/cast_def_0_133.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_133.jpeg
#   inflating: train_data/cast_def_0_324.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_324.jpeg
#   inflating: train_data/cast_ok_0_440.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_440.jpeg
#   inflating: train_data/cast_ok_0_339.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_339.jpeg
#   inflating: train_data/cast_def_0_148.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_148.jpeg
#   inflating: train_data/cast_ok_0_381.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_381.jpeg
#   inflating: train_data/cast_def_0_109.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_109.jpeg
#   inflating: train_data/cast_ok_0_397.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_397.jpeg
#   inflating: train_data/cast_ok_0_421.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_421.jpeg
#   inflating: train_data/cast_def_0_200.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_200.jpeg
#   inflating: train_data/cast_def_0_191.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_191.jpeg
#   inflating: train_data/cast_ok_0_460.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_460.jpeg
#   inflating: train_data/cast_def_0_2518.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2518.jpeg
#   inflating: train_data/cast_def_0_304.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_304.jpeg
#   inflating: train_data/cast_ok_0_175.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_175.jpeg
#   inflating: train_data/cast_def_0_2471.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2471.jpeg
#   inflating: train_data/cast_def_0_11.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_11.jpeg
#   inflating: train_data/cast_ok_0_362.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_362.jpeg
#   inflating: train_data/cast_def_0_2426.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2426.jpeg
#   inflating: train_data/cast_def_0_105.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_105.jpeg
#   inflating: train_data/cast_def_0_50.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_50.jpeg
#   inflating: train_data/cast_ok_0_266.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_266.jpeg
#   inflating: train_data/cast_def_0_2522.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2522.jpeg
#   inflating: train_data/cast_def_0_2467.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2467.jpeg
#   inflating: train_data/cast_def_0_2389.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2389.jpeg
#   inflating: train_data/cast_def_0_203.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_203.jpeg
#   inflating: train_data/cast_def_0_192.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_192.jpeg
#   inflating: train_data/cast_ok_0_249.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_249.jpeg
#   inflating: train_data/cast_ok_0_463.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_463.jpeg
#   inflating: train_data/cast_def_0_350.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_350.jpeg
#   inflating: train_data/cast_ok_0_434.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_434.jpeg
#   inflating: train_data/cast_def_0_69.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_69.jpeg
#   inflating: train_data/cast_def_0_215.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_215.jpeg
#   inflating: train_data/cast_def_0_2409.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2409.jpeg
#   inflating: train_data/cast_ok_0_273.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_273.jpeg
#   inflating: train_data/cast_def_0_110.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_110.jpeg
#   inflating: train_data/cast_ok_0_361.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_361.jpeg
#   inflating: train_data/cast_def_0_2425.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2425.jpeg
#   inflating: train_data/cast_ok_0_418.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_418.jpeg
#   inflating: train_data/cast_ok_0_398.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_398.jpeg
#   inflating: train_data/cast_def_0_53.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_53.jpeg
#   inflating: train_data/cast_def_0_2433.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2433.jpeg
#   inflating: train_data/cast_ok_0_357.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_357.jpeg
#   inflating: train_data/cast_def_0_126.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_126.jpeg
#   inflating: train_data/cast_def_0_2385.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2385.jpeg
#   inflating: train_data/cast_def_0_2501.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2501.jpeg
#   inflating: train_data/cast_def_0_24.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_24.jpeg
#   inflating: train_data/cast_ok_0_300.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_300.jpeg
#   inflating: train_data/cast_ok_0_316.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_316.jpeg
#   inflating: train_data/cast_def_0_2405.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2405.jpeg
#   inflating: train_data/cast_def_0_130.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_130.jpeg
#   inflating: train_data/cast_def_0_327.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_327.jpeg
#   inflating: train_data/cast_def_0_2491.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2491.jpeg
#   inflating: train_data/cast_def_0_8.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_8.jpeg
#   inflating: train_data/cast_ok_0_402.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_402.jpeg
#   inflating: train_data/cast_def_0_331.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_331.jpeg
#   inflating: train_data/cast_ok_0_269.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_269.jpeg
#   inflating: train_data/cast_ok_0_286.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_286.jpeg
#   inflating: train_data/cast_ok_0_454.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_454.jpeg
#   inflating: train_data/cast_def_0_2469.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2469.jpeg
#   inflating: train_data/cast_def_0_330.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_330.jpeg
#   inflating: train_data/cast_ok_0_415.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_415.jpeg
#   inflating: train_data/cast_def_0_9.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_9.jpeg
#   inflating: train_data/cast_ok_0_157.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_157.jpeg
#   inflating: train_data/cast_def_0_2490.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2490.jpeg
#   inflating: train_data/cast_def_0_131.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_131.jpeg
#   inflating: train_data/cast_ok_0_205.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_205.jpeg
#   inflating: train_data/cast_def_0_2404.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2404.jpeg
#   inflating: train_data/cast_def_0_33.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_33.jpeg
#   inflating: train_data/cast_ok_0_244.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_244.jpeg
#   inflating: train_data/cast_def_0_2500.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2500.jpeg
#   inflating: train_data/cast_ok_0_182.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_182.jpeg
#   inflating: train_data/cast_def_0_25.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_25.jpeg
#   inflating: train_data/cast_def_0_2384.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2384.jpeg
#   inflating: train_data/cast_ok_0_213.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_213.jpeg
#   inflating: train_data/cast_def_0_2432.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2432.jpeg
#   inflating: train_data/cast_ok_0_233.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_233.jpeg
#   inflating: train_data/cast_ok_0_376.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_376.jpeg
#   inflating: train_data/cast_def_0_107.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_107.jpeg
#   inflating: train_data/cast_ok_0_360.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_360.jpeg
#   inflating: train_data/cast_def_0_13.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_13.jpeg
#   inflating: train_data/cast_ok_0_435.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_435.jpeg
#   inflating: train_data/cast_def_0_68.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_68.jpeg
#   inflating: train_data/cast_ok_0_198.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_198.jpeg
#   inflating: train_data/cast_def_0_310.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_310.jpeg
#   inflating: train_data/cast_def_0_193.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_193.jpeg
#   inflating: train_data/cast_ok_0_248.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_248.jpeg
#   inflating: train_data/cast_def_0_91.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_91.jpeg
#   inflating: train_data/cast_def_0_347.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_347.jpeg
#   inflating: train_data/cast_def_0_2415.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2415.jpeg
#   inflating: train_data/cast_def_0_120.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_120.jpeg
#   inflating: train_data/cast_def_0_2383.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2383.jpeg
#   inflating: train_data/cast_ok_0_193.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_193.jpeg
#   inflating: train_data/cast_def_0_2403.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2403.jpeg
#   inflating: train_data/cast_def_0_136.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_136.jpeg
#   inflating: train_data/cast_def_0_2478.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2478.jpeg
#   inflating: train_data/cast_def_0_321.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_321.jpeg
#   inflating: train_data/cast_ok_0_296.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_296.jpeg
#   inflating: train_data/cast_def_0_360.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_360.jpeg
#   inflating: train_data/cast_ok_0_392.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_392.jpeg
#   inflating: train_data/cast_def_0_337.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_337.jpeg
#   inflating: train_data/cast_ok_0_424.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_424.jpeg
#   inflating: train_data/cast_def_0_194.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_194.jpeg
#   inflating: train_data/cast_def_0_317.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_317.jpeg
#   inflating: train_data/cast_ok_0_189.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_189.jpeg
#   inflating: train_data/cast_ok_0_170.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_170.jpeg
#   inflating: train_data/cast_ok_0_465.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_465.jpeg
#   inflating: train_data/cast_ok_0_432.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_432.jpeg
#   inflating: train_data/cast_def_0_2474.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2474.jpeg
#   inflating: train_data/cast_ok_0_367.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_367.jpeg
#   inflating: train_data/cast_def_0_116.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_116.jpeg
#   inflating: train_data/cast_def_0_43.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_43.jpeg
#   inflating: train_data/cast_def_0_2.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2.jpeg
#   inflating: train_data/cast_def_0_2435.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2435.jpeg
#   inflating: train_data/cast_def_0_55.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_55.jpeg
#   inflating: train_data/cast_ok_0_263.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_263.jpeg
#   inflating: train_data/cast_def_0_2527.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2527.jpeg
#   inflating: train_data/cast_def_0_2526.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2526.jpeg
#   inflating: train_data/cast_ok_0_262.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_262.jpeg
#   inflating: train_data/cast_ok_0_327.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_327.jpeg
#   inflating: train_data/cast_def_0_2434.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2434.jpeg
#   inflating: train_data/cast_def_0_54.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_54.jpeg
#   inflating: train_data/cast_ok_0_370.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_370.jpeg
#   inflating: train_data/cast_def_0_15.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_15.jpeg
#   inflating: train_data/cast_ok_0_331.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_331.jpeg
#   inflating: train_data/cast_def_0_81.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_81.jpeg
#   inflating: train_data/cast_def_0_357.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_357.jpeg
#   inflating: train_data/cast_ok_0_171.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_171.jpeg
#   inflating: train_data/cast_ok_0_167.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_167.jpeg
#   inflating: train_data/cast_ok_0_188.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_188.jpeg
#   inflating: train_data/cast_ok_0_472.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_472.jpeg
#   inflating: train_data/cast_def_0_97.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_97.jpeg
#   inflating: train_data/cast_ok_0_425.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_425.jpeg
#   inflating: train_data/cast_def_0_204.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_204.jpeg
#   inflating: train_data/cast_ok_0_452.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_452.jpeg
#   inflating: train_data/cast_ok_0_147.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_147.jpeg
#   inflating: train_data/cast_ok_0_239.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_239.jpeg
#   inflating: train_data/cast_ok_0_405.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_405.jpeg
#   inflating: train_data/cast_ok_0_413.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_413.jpeg
#   inflating: train_data/cast_ok_0_278.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_278.jpeg
#   inflating: train_data/cast_ok_0_444.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_444.jpeg
#   inflating: train_data/cast_def_0_19.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_19.jpeg
#   inflating: train_data/cast_def_0_320.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_320.jpeg
#   inflating: train_data/cast_ok_0_346.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_346.jpeg
#   inflating: train_data/cast_ok_0_307.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_307.jpeg
#   inflating: train_data/cast_ok_0_242.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_242.jpeg
#   inflating: train_data/cast_def_0_2506.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_2506.jpeg
#   inflating: train_data/cast_ok_0_184.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_184.jpeg
#   inflating: train_data/cast_ok_0_350.jpeg
#   inflating: __MACOSX/train_data/._cast_ok_0_350.jpeg
#   inflating: train_data/cast_def_0_74.jpeg
#   inflating: __MACOSX/train_data/._cast_def_0_74.jpeg

# %%
# ディレクトリ内のデータの確認
# %ls
# Out:
# adc.json   sample_data/           test_data.zip  train_data/
# __MACOSX/  sample_submission.csv  train.csv      train_data.zip

# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# ライブラリのインポート
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

from sklearn.model_selection import train_test_split

import torch
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset
from torchvision.io import read_image
from torch.utils.data import DataLoader
from torch import nn, optim

from collections import defaultdict

'''
定数の指定
'''

# 学習データのラベルマスター
train_master_path = './train.csv'

# 画像データのディレクトリ
img_dir = './train_data/' # 画像データのディレクトリ

# リサイズする画像サイズ
photo_size = 300

# バッチサイズ
batch_size = 4

# クラス数の定義
num_classes = 2

# 学習率
lr = 0.001

# 学習済み
pretrained = True

# エポック数
epochs = 200

# 保存先のパス
save_path = '/content/drive/My Drive/Colab Notebooks/SIGNATE/casting_pytorch/model/casting_pytorch_fine-tuning_Epoch'

# 学習に使用する機器(device)の設定
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'デバイス：{device}')

'''
データの読み込み
'''

# ラベルデータの読み込み
train_master = pd.read_csv(train_master_path, sep=',')
print(train_master.head())

# 画像データの名前リストの抽出
image_name_list = train_master['id'].values

# ラベルリストの抽出
label_list = train_master['target'].values

'''
前処理とデータセットの作成
'''

# 学習データと検証データに分割
x_train, x_val, y_train, y_val = train_test_split(image_name_list, label_list, test_size=0.25, stratify=label_list, random_state=42)

# transformの設定
transform = {
    'train': transforms.Compose([
        transforms.Resize(photo_size),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]),
    'val': transforms.Compose([
        transforms.Resize(photo_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]),
}

# Datasetの設定
class CastingDataset(Dataset):
    def __init__(self, image_name_list, label_list, img_dir, phase=None):
        self.image_name_list = image_name_list # 画像ファイル名
        self.label_list = label_list # ラベル
        self.img_dir = img_dir # 画像データのディレクトリ
        self.phase = phase # 変数phaseで学習(train)もしくは検証(val)の設定を行う
        self.transform = transform

    def __len__(self):
        return len(self.image_name_list) # 1エポックあたりに読み込むデータ数として、入力データの数を指定

    def __getitem__(self, index):
        
        # index番目の画像を読み込み、前処理を行う
        image_path = os.path.join(self.img_dir, self.image_name_list[index]) # train_master.iloc[index, 0]はファイル名を抽出
        img = Image.open(image_path)
        img = self.transform[self.phase](img)
        
        # index番目のラベルを取得する
        label = self.label_list[index]
        
        return img, label

# Datasetのインスタンス作成
train_dataset = CastingDataset(x_train, y_train, img_dir, phase='train')
val_dataset = CastingDataset(x_val, y_val, img_dir, phase='val')

# Dataloader
dataloader = {
    'train': DataLoader(train_dataset, batch_size=batch_size, shuffle=True),
    'val': DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    }

'''
モデルの定義
'''

model = models.mobilenet_v3_large(pretrained=pretrained)
fc_in_features = model.classifier[3].out_features # 最終レイヤー関数の次元数
model.fc = nn.Linear(fc_in_features, num_classes) # 最終レイヤー関数の付け替え
print(model)

'''
Fine-tunigの設定
'''

# ファインチューニングで学習させるパラメータを、変数params_to_updateの1～3に格納する

params_to_update_1 = []
params_to_update_2 = []

# 学習させる層のパラメータ名を指定
update_param_names_1 = ["features"]
update_param_names_2 = ["classifier.0.weight", "classifier.0.bias",
                        "classifier.3.weight", "classifier.3.bias"]

# パラメータごとに各リストに格納する
for name, param in model.named_parameters():
    if update_param_names_1[0] in name:
        param.requires_grad = True
        params_to_update_1.append(param)
        print("params_to_update_1に格納：", name)

    elif name in update_param_names_2:
        param.requires_grad = True
        params_to_update_2.append(param)
        print("params_to_update_2に格納：", name)

    else:
        param.requires_grad = False
        print("勾配計算なし。学習しない：", name)

# モデルをGPUに送る
model.to(device)

'''
学習
'''

# 損失関数の定義
criterion = nn.CrossEntropyLoss()

# 最適化手法の設定
optimizer = optim.Adam([
    {'params': params_to_update_1, 'lr': 1e-5},
    {'params': params_to_update_2, 'lr': 1e-4}
])

history = defaultdict(list)

# 学習モデルの定義
def train_model(model, epochs, loss_fn, optimizer):
    
    # ベストスコアの初期化
    best_loss = np.inf
    
    # エポックループの設定
    for epoch in range(epochs):
        
        # 現在のエポック数の出力
        print(f'Epoch: {epoch+1} / {epochs}')
        print('--------------------------')
        
         # 毎エポック: 学習・検証ループの設定
        for phase in ['train', 'val']:
            
            # 学習モード、検証モードの切替
            if phase == 'train':
                model.train()
            else:
                model.eval()
            
            # 損失値のリセット
            running_loss = 0.0
            # 正解数
            corrects = 0
            # 予測値リストのリセット
            pred_list = []
            # 正解値リストのリセット
            true_list = []
            
            # dataloaderから、ミニバッチ(batch_size)単位でのデータの読み込み
            for images, labels in dataloader[phase]:
                
                # 入力データ、正解ラベルをモデルと同じdeviceへ移動
                images = images.to(device)
                labels = labels.to(device)
                
                # 勾配情報の初期化
                optimizer.zero_grad()
                
                # 学習時のみ勾配情報を有効に
                with torch.set_grad_enabled(phase=='train'):
                    
                    # モデルによる計算
                    outputs = model(images)
                    # 損失値の計算
                    loss = loss_fn(outputs, labels)
                    # 予測ラベルの算出
                    preds = torch.argmax(outputs, dim=1) # 予測値を出力
                    
                    # 学習時のみ、バックプロパゲーションとパラメータ更新
                    if phase == 'train':
                        
                        # 誤差逆伝播法により勾配の算出
                        loss.backward()
                        # optimizerのパラメータ更新
                        optimizer.step()
                    
                    # 損失値の追加
                    running_loss += loss.item() * images.size(0)
                    
                    # 正解数の追加
                    corrects += torch.sum(preds == labels.data)                    
                    
                    # 予測ラベルの追加
                    preds = preds.to('cpu').numpy()
                    pred_list.extend(preds)
                    
                    # 正解ラベルの追加
                    labels = labels.to('cpu').numpy()
                    true_list.extend(labels)
            
            # 1エポック内における損失値の平均
            epoch_loss = running_loss / len(dataloader[phase].dataset)
            
            # 正解率の算出
            accuracy = corrects.double() / len(dataloader[phase].dataset)
            
            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_accuracy'].append(accuracy)
            
            # 各評価スコアの出力
            print(f'{phase} Loss: {epoch_loss:.4f} Accuracy: {accuracy:.4f}')
            
            # 検証時、検証スコアとベストスコアの大小比較を行う
            if (phase == 'val') and (epoch_loss < best_loss):
                
                ## 検証スコアが改善した場合のみ以下の処理を行う
                
                # ベストスコアの更新
                best_loss = epoch_loss
                # パラメータの名前を指定
                param_name = f'{save_path}{epoch+1}_logloss_{epoch_loss:.4f}.pth'
                # パラメータの保存
                torch.save(model.state_dict(), param_name)
    
    # 正解率の推移をプロット
    plt.plot(history['train_accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('Accuracy')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()
    
    # ロスの推移をプロット
    plt.plot(history['train_loss'])
    plt.plot(history['val_loss'])
    plt.title('Loss')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

'''
モデルの学習と推論の実行
'''

train_model(model, epochs, criterion, optimizer)
# Out:
# デバイス：cuda
#                     id  target
# 0  cast_def_0_335.jpeg       0
# 1  cast_def_0_323.jpeg       0
# 2   cast_def_0_61.jpeg       0
# 3  cast_def_0_163.jpeg       0
# 4  cast_def_0_175.jpeg       0
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_large-8738ca79.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_large-8738ca79.pth
#   0%|          | 0.00/21.1M [00:00<?, ?B/s]
# MobileNetV3(
#   (features): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#           (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(64, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(72, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#           (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(200, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#           (1): BatchNorm2d(184, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(184, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (13): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (14): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (15): InvertedResidual(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (16): ConvNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=960, out_features=1280, bias=True)
#     (1): Hardswish()
#     (2): Dropout(p=0.2, inplace=True)
#     (3): Linear(in_features=1280, out_features=1000, bias=True)
#   )
#   (fc): Linear(in_features=1000, out_features=2, bias=True)
# )
# params_to_update_1に格納： features.0.0.weight
# params_to_update_1に格納： features.0.1.weight
# params_to_update_1に格納： features.0.1.bias
# params_to_update_1に格納： features.1.block.0.0.weight
# params_to_update_1に格納： features.1.block.0.1.weight
# params_to_update_1に格納： features.1.block.0.1.bias
# params_to_update_1に格納： features.1.block.1.0.weight
# params_to_update_1に格納： features.1.block.1.1.weight
# params_to_update_1に格納： features.1.block.1.1.bias
# params_to_update_1に格納： features.2.block.0.0.weight
# params_to_update_1に格納： features.2.block.0.1.weight
# params_to_update_1に格納： features.2.block.0.1.bias
# params_to_update_1に格納： features.2.block.1.0.weight
# params_to_update_1に格納： features.2.block.1.1.weight
# params_to_update_1に格納： features.2.block.1.1.bias
# params_to_update_1に格納： features.2.block.2.0.weight
# params_to_update_1に格納： features.2.block.2.1.weight
# params_to_update_1に格納： features.2.block.2.1.bias
# params_to_update_1に格納： features.3.block.0.0.weight
# params_to_update_1に格納： features.3.block.0.1.weight
# params_to_update_1に格納： features.3.block.0.1.bias
# params_to_update_1に格納： features.3.block.1.0.weight
# params_to_update_1に格納： features.3.block.1.1.weight
# params_to_update_1に格納： features.3.block.1.1.bias
# params_to_update_1に格納： features.3.block.2.0.weight
# params_to_update_1に格納： features.3.block.2.1.weight
# params_to_update_1に格納： features.3.block.2.1.bias
# params_to_update_1に格納： features.4.block.0.0.weight
# params_to_update_1に格納： features.4.block.0.1.weight
# params_to_update_1に格納： features.4.block.0.1.bias
# params_to_update_1に格納： features.4.block.1.0.weight
# params_to_update_1に格納： features.4.block.1.1.weight
# params_to_update_1に格納： features.4.block.1.1.bias
# params_to_update_1に格納： features.4.block.2.fc1.weight
# params_to_update_1に格納： features.4.block.2.fc1.bias
# params_to_update_1に格納： features.4.block.2.fc2.weight
# params_to_update_1に格納： features.4.block.2.fc2.bias
# params_to_update_1に格納： features.4.block.3.0.weight
# params_to_update_1に格納： features.4.block.3.1.weight
# params_to_update_1に格納： features.4.block.3.1.bias
# params_to_update_1に格納： features.5.block.0.0.weight
# params_to_update_1に格納： features.5.block.0.1.weight
# params_to_update_1に格納： features.5.block.0.1.bias
# params_to_update_1に格納： features.5.block.1.0.weight
# params_to_update_1に格納： features.5.block.1.1.weight
# params_to_update_1に格納： features.5.block.1.1.bias
# params_to_update_1に格納： features.5.block.2.fc1.weight
# params_to_update_1に格納： features.5.block.2.fc1.bias
# params_to_update_1に格納： features.5.block.2.fc2.weight
# params_to_update_1に格納： features.5.block.2.fc2.bias
# params_to_update_1に格納： features.5.block.3.0.weight
# params_to_update_1に格納： features.5.block.3.1.weight
# params_to_update_1に格納： features.5.block.3.1.bias
# params_to_update_1に格納： features.6.block.0.0.weight
# params_to_update_1に格納： features.6.block.0.1.weight
# params_to_update_1に格納： features.6.block.0.1.bias
# params_to_update_1に格納： features.6.block.1.0.weight
# params_to_update_1に格納： features.6.block.1.1.weight
# params_to_update_1に格納： features.6.block.1.1.bias
# params_to_update_1に格納： features.6.block.2.fc1.weight
# params_to_update_1に格納： features.6.block.2.fc1.bias
# params_to_update_1に格納： features.6.block.2.fc2.weight
# params_to_update_1に格納： features.6.block.2.fc2.bias
# params_to_update_1に格納： features.6.block.3.0.weight
# params_to_update_1に格納： features.6.block.3.1.weight
# params_to_update_1に格納： features.6.block.3.1.bias
# params_to_update_1に格納： features.7.block.0.0.weight
# params_to_update_1に格納： features.7.block.0.1.weight
# params_to_update_1に格納： features.7.block.0.1.bias
# params_to_update_1に格納： features.7.block.1.0.weight
# params_to_update_1に格納： features.7.block.1.1.weight
# params_to_update_1に格納： features.7.block.1.1.bias
# params_to_update_1に格納： features.7.block.2.0.weight
# params_to_update_1に格納： features.7.block.2.1.weight
# params_to_update_1に格納： features.7.block.2.1.bias
# params_to_update_1に格納： features.8.block.0.0.weight
# params_to_update_1に格納： features.8.block.0.1.weight
# params_to_update_1に格納： features.8.block.0.1.bias
# params_to_update_1に格納： features.8.block.1.0.weight
# params_to_update_1に格納： features.8.block.1.1.weight
# params_to_update_1に格納： features.8.block.1.1.bias
# params_to_update_1に格納： features.8.block.2.0.weight
# params_to_update_1に格納： features.8.block.2.1.weight
# params_to_update_1に格納： features.8.block.2.1.bias
# params_to_update_1に格納： features.9.block.0.0.weight
# params_to_update_1に格納： features.9.block.0.1.weight
# params_to_update_1に格納： features.9.block.0.1.bias
# params_to_update_1に格納： features.9.block.1.0.weight
# params_to_update_1に格納： features.9.block.1.1.weight
# params_to_update_1に格納： features.9.block.1.1.bias
# params_to_update_1に格納： features.9.block.2.0.weight
# params_to_update_1に格納： features.9.block.2.1.weight
# params_to_update_1に格納： features.9.block.2.1.bias
# params_to_update_1に格納： features.10.block.0.0.weight
# params_to_update_1に格納： features.10.block.0.1.weight
# params_to_update_1に格納： features.10.block.0.1.bias
# params_to_update_1に格納： features.10.block.1.0.weight
# params_to_update_1に格納： features.10.block.1.1.weight
# params_to_update_1に格納： features.10.block.1.1.bias
# params_to_update_1に格納： features.10.block.2.0.weight
# params_to_update_1に格納： features.10.block.2.1.weight
# params_to_update_1に格納： features.10.block.2.1.bias
# params_to_update_1に格納： features.11.block.0.0.weight
# params_to_update_1に格納： features.11.block.0.1.weight
# params_to_update_1に格納： features.11.block.0.1.bias
# params_to_update_1に格納： features.11.block.1.0.weight
# params_to_update_1に格納： features.11.block.1.1.weight
# params_to_update_1に格納： features.11.block.1.1.bias
# params_to_update_1に格納： features.11.block.2.fc1.weight
# params_to_update_1に格納： features.11.block.2.fc1.bias
# params_to_update_1に格納： features.11.block.2.fc2.weight
# params_to_update_1に格納： features.11.block.2.fc2.bias
# params_to_update_1に格納： features.11.block.3.0.weight
# params_to_update_1に格納： features.11.block.3.1.weight
# params_to_update_1に格納： features.11.block.3.1.bias
# params_to_update_1に格納： features.12.block.0.0.weight
# params_to_update_1に格納： features.12.block.0.1.weight
# params_to_update_1に格納： features.12.block.0.1.bias
# params_to_update_1に格納： features.12.block.1.0.weight
# params_to_update_1に格納： features.12.block.1.1.weight
# params_to_update_1に格納： features.12.block.1.1.bias
# params_to_update_1に格納： features.12.block.2.fc1.weight
# params_to_update_1に格納： features.12.block.2.fc1.bias
# params_to_update_1に格納： features.12.block.2.fc2.weight
# params_to_update_1に格納： features.12.block.2.fc2.bias
# params_to_update_1に格納： features.12.block.3.0.weight
# params_to_update_1に格納： features.12.block.3.1.weight
# params_to_update_1に格納： features.12.block.3.1.bias
# params_to_update_1に格納： features.13.block.0.0.weight
# params_to_update_1に格納： features.13.block.0.1.weight
# params_to_update_1に格納： features.13.block.0.1.bias
# params_to_update_1に格納： features.13.block.1.0.weight
# params_to_update_1に格納： features.13.block.1.1.weight
# params_to_update_1に格納： features.13.block.1.1.bias
# params_to_update_1に格納： features.13.block.2.fc1.weight
# params_to_update_1に格納： features.13.block.2.fc1.bias
# params_to_update_1に格納： features.13.block.2.fc2.weight
# params_to_update_1に格納： features.13.block.2.fc2.bias
# params_to_update_1に格納： features.13.block.3.0.weight
# params_to_update_1に格納： features.13.block.3.1.weight
# params_to_update_1に格納： features.13.block.3.1.bias
# params_to_update_1に格納： features.14.block.0.0.weight
# params_to_update_1に格納： features.14.block.0.1.weight
# params_to_update_1に格納： features.14.block.0.1.bias
# params_to_update_1に格納： features.14.block.1.0.weight
# params_to_update_1に格納： features.14.block.1.1.weight
# params_to_update_1に格納： features.14.block.1.1.bias
# params_to_update_1に格納： features.14.block.2.fc1.weight
# params_to_update_1に格納： features.14.block.2.fc1.bias
# params_to_update_1に格納： features.14.block.2.fc2.weight
# params_to_update_1に格納： features.14.block.2.fc2.bias
# params_to_update_1に格納： features.14.block.3.0.weight
# params_to_update_1に格納： features.14.block.3.1.weight
# params_to_update_1に格納： features.14.block.3.1.bias
# params_to_update_1に格納： features.15.block.0.0.weight
# params_to_update_1に格納： features.15.block.0.1.weight
# params_to_update_1に格納： features.15.block.0.1.bias
# params_to_update_1に格納： features.15.block.1.0.weight
# params_to_update_1に格納： features.15.block.1.1.weight
# params_to_update_1に格納： features.15.block.1.1.bias
# params_to_update_1に格納： features.15.block.2.fc1.weight
# params_to_update_1に格納： features.15.block.2.fc1.bias
# params_to_update_1に格納： features.15.block.2.fc2.weight
# params_to_update_1に格納： features.15.block.2.fc2.bias
# params_to_update_1に格納： features.15.block.3.0.weight
# params_to_update_1に格納： features.15.block.3.1.weight
# params_to_update_1に格納： features.15.block.3.1.bias
# params_to_update_1に格納： features.16.0.weight
# params_to_update_1に格納： features.16.1.weight
# params_to_update_1に格納： features.16.1.bias
# params_to_update_2に格納： classifier.0.weight
# params_to_update_2に格納： classifier.0.bias
# params_to_update_2に格納： classifier.3.weight
# params_to_update_2に格納： classifier.3.bias
# 勾配計算なし。学習しない： fc.weight
# 勾配計算なし。学習しない： fc.bias
# Epoch: 1 / 200
# --------------------------
# train Loss: 1.5735 Accuracy: 0.6310
# val Loss: 2.5922 Accuracy: 0.1587
# Epoch: 2 / 200
# --------------------------
# train Loss: 0.4827 Accuracy: 0.7807
# val Loss: 1.2240 Accuracy: 0.5714
# Epoch: 3 / 200
# --------------------------
# train Loss: 0.3726 Accuracy: 0.8182
# val Loss: 1.2655 Accuracy: 0.4444
# Epoch: 4 / 200
# --------------------------
# train Loss: 0.2608 Accuracy: 0.8770
# val Loss: 1.1597 Accuracy: 0.4762
# Epoch: 5 / 200
# --------------------------
# train Loss: 0.2354 Accuracy: 0.9091
# val Loss: 1.1694 Accuracy: 0.4762
# Epoch: 6 / 200
# --------------------------
# train Loss: 0.2843 Accuracy: 0.8984
# val Loss: 0.5941 Accuracy: 0.7460
# Epoch: 7 / 200
# --------------------------
# train Loss: 0.2811 Accuracy: 0.8984
# val Loss: 0.4708 Accuracy: 0.8095
# Epoch: 8 / 200
# --------------------------
# train Loss: 0.1528 Accuracy: 0.9519
# val Loss: 0.3677 Accuracy: 0.8413
# Epoch: 9 / 200
# --------------------------
# train Loss: 0.1669 Accuracy: 0.9358
# val Loss: 0.2172 Accuracy: 0.9048
# Epoch: 10 / 200
# --------------------------
# train Loss: 0.1072 Accuracy: 0.9626
# val Loss: 0.1380 Accuracy: 0.9683
# Epoch: 11 / 200
# --------------------------
# train Loss: 0.1902 Accuracy: 0.9091
# val Loss: 0.1222 Accuracy: 0.9683
# Epoch: 12 / 200
# --------------------------
# train Loss: 0.2253 Accuracy: 0.8877
# val Loss: 0.2742 Accuracy: 0.8730
# Epoch: 13 / 200
# --------------------------
# train Loss: 0.0974 Accuracy: 0.9733
# val Loss: 0.1591 Accuracy: 0.9365
# Epoch: 14 / 200
# --------------------------
# train Loss: 0.0805 Accuracy: 0.9679
# val Loss: 0.1600 Accuracy: 0.8730
# Epoch: 15 / 200
# --------------------------
# train Loss: 0.0814 Accuracy: 0.9572
# val Loss: 0.2187 Accuracy: 0.8730
# Epoch: 16 / 200
# --------------------------
# train Loss: 0.2025 Accuracy: 0.8984
# val Loss: 0.0358 Accuracy: 1.0000
# Epoch: 17 / 200
# --------------------------
# train Loss: 0.1718 Accuracy: 0.9305
# val Loss: 0.0349 Accuracy: 1.0000
# Epoch: 18 / 200
# --------------------------
# train Loss: 0.0596 Accuracy: 0.9786
# val Loss: 0.0299 Accuracy: 1.0000
# Epoch: 19 / 200
# --------------------------
# train Loss: 0.0872 Accuracy: 0.9572
# val Loss: 0.0257 Accuracy: 1.0000
# Epoch: 20 / 200
# --------------------------
# train Loss: 0.1455 Accuracy: 0.9305
# val Loss: 0.0269 Accuracy: 1.0000
# Epoch: 21 / 200
# --------------------------
# train Loss: 0.1097 Accuracy: 0.9679
# val Loss: 0.0280 Accuracy: 0.9841
# Epoch: 22 / 200
# --------------------------
# train Loss: 0.1721 Accuracy: 0.9305
# val Loss: 0.0212 Accuracy: 1.0000
# Epoch: 23 / 200
# --------------------------
# train Loss: 0.0415 Accuracy: 0.9947
# val Loss: 0.0149 Accuracy: 1.0000
# Epoch: 24 / 200
# --------------------------
# train Loss: 0.0329 Accuracy: 1.0000
# val Loss: 0.0128 Accuracy: 1.0000
# Epoch: 25 / 200
# --------------------------
# train Loss: 0.0381 Accuracy: 0.9947
# val Loss: 0.0425 Accuracy: 1.0000
# Epoch: 26 / 200
# --------------------------
# train Loss: 0.0541 Accuracy: 0.9893
# val Loss: 0.0164 Accuracy: 1.0000
# Epoch: 27 / 200
# --------------------------
# train Loss: 0.0718 Accuracy: 0.9840
# val Loss: 0.0212 Accuracy: 1.0000
# Epoch: 28 / 200
# --------------------------
# train Loss: 0.0543 Accuracy: 0.9733
# val Loss: 0.0185 Accuracy: 1.0000
# Epoch: 29 / 200
# --------------------------
# train Loss: 0.1114 Accuracy: 0.9519
# val Loss: 0.0168 Accuracy: 1.0000
# Epoch: 30 / 200
# --------------------------
# train Loss: 0.0337 Accuracy: 0.9840
# val Loss: 0.0510 Accuracy: 0.9841
# Epoch: 31 / 200
# --------------------------
# train Loss: 0.0490 Accuracy: 0.9786
# val Loss: 0.0455 Accuracy: 0.9841
# Epoch: 32 / 200
# --------------------------
# train Loss: 0.0207 Accuracy: 0.9947
# val Loss: 0.0192 Accuracy: 1.0000
# Epoch: 33 / 200
# --------------------------
# train Loss: 0.0819 Accuracy: 0.9626
# val Loss: 0.0301 Accuracy: 1.0000
# Epoch: 34 / 200
# --------------------------
# train Loss: 0.0308 Accuracy: 0.9893
# val Loss: 0.0141 Accuracy: 1.0000
# Epoch: 35 / 200
# --------------------------
# train Loss: 0.0443 Accuracy: 0.9786
# val Loss: 0.0395 Accuracy: 0.9841
# Epoch: 36 / 200
# --------------------------
# train Loss: 0.0748 Accuracy: 0.9786
# val Loss: 0.0143 Accuracy: 1.0000
# Epoch: 37 / 200
# --------------------------
# train Loss: 0.1639 Accuracy: 0.9412
# val Loss: 0.0140 Accuracy: 1.0000
# Epoch: 38 / 200
# --------------------------
# train Loss: 0.1152 Accuracy: 0.9679
# val Loss: 0.0472 Accuracy: 0.9841
# Epoch: 39 / 200
# --------------------------
# train Loss: 0.0488 Accuracy: 0.9840
# val Loss: 0.0091 Accuracy: 1.0000
# Epoch: 40 / 200
# --------------------------
# train Loss: 0.0205 Accuracy: 0.9947
# val Loss: 0.0060 Accuracy: 1.0000
# Epoch: 41 / 200
# --------------------------
# train Loss: 0.0490 Accuracy: 0.9733
# val Loss: 0.0553 Accuracy: 0.9683
# Epoch: 42 / 200
# --------------------------
# train Loss: 0.0210 Accuracy: 1.0000
# val Loss: 0.0086 Accuracy: 1.0000
# Epoch: 43 / 200
# --------------------------
# train Loss: 0.0951 Accuracy: 0.9572
# val Loss: 0.0418 Accuracy: 0.9841
# Epoch: 44 / 200
# --------------------------
# train Loss: 0.0216 Accuracy: 1.0000
# val Loss: 0.0068 Accuracy: 1.0000
# Epoch: 45 / 200
# --------------------------
# train Loss: 0.1021 Accuracy: 0.9572
# val Loss: 0.0105 Accuracy: 1.0000
# Epoch: 46 / 200
# --------------------------
# train Loss: 0.1342 Accuracy: 0.9465
# val Loss: 0.0119 Accuracy: 1.0000
# Epoch: 47 / 200
# --------------------------
# train Loss: 0.0680 Accuracy: 0.9840
# val Loss: 0.0473 Accuracy: 0.9841
# Epoch: 48 / 200
# --------------------------
# train Loss: 0.0289 Accuracy: 1.0000
# val Loss: 0.0080 Accuracy: 1.0000
# Epoch: 49 / 200
# --------------------------
# train Loss: 0.0582 Accuracy: 0.9786
# val Loss: 0.0049 Accuracy: 1.0000
# Epoch: 50 / 200
# --------------------------
# train Loss: 0.0365 Accuracy: 0.9893
# val Loss: 0.0326 Accuracy: 1.0000
# Epoch: 51 / 200
# --------------------------
# train Loss: 0.0354 Accuracy: 0.9893
# val Loss: 0.0083 Accuracy: 1.0000
# Epoch: 52 / 200
# --------------------------
# train Loss: 0.0213 Accuracy: 0.9947
# val Loss: 0.0042 Accuracy: 1.0000
# Epoch: 53 / 200
# --------------------------
# train Loss: 0.0150 Accuracy: 1.0000
# val Loss: 0.0043 Accuracy: 1.0000
# Epoch: 54 / 200
# --------------------------
# train Loss: 0.0447 Accuracy: 0.9840
# val Loss: 0.0509 Accuracy: 0.9683
# Epoch: 55 / 200
# --------------------------
# train Loss: 0.0131 Accuracy: 1.0000
# val Loss: 0.0043 Accuracy: 1.0000
# Epoch: 56 / 200
# --------------------------
# train Loss: 0.0178 Accuracy: 0.9947
# val Loss: 0.0448 Accuracy: 0.9841
# Epoch: 57 / 200
# --------------------------
# train Loss: 0.0506 Accuracy: 0.9786
# val Loss: 0.0046 Accuracy: 1.0000
# Epoch: 58 / 200
# --------------------------
# train Loss: 0.0621 Accuracy: 0.9786
# val Loss: 0.0366 Accuracy: 0.9841
# Epoch: 59 / 200
# --------------------------
# train Loss: 0.0241 Accuracy: 0.9840
# val Loss: 0.0130 Accuracy: 1.0000
# Epoch: 60 / 200
# --------------------------
# train Loss: 0.0470 Accuracy: 0.9840
# val Loss: 0.0037 Accuracy: 1.0000
# Epoch: 61 / 200
# --------------------------
# train Loss: 0.0161 Accuracy: 0.9947
# val Loss: 0.0197 Accuracy: 1.0000
# Epoch: 62 / 200
# --------------------------
# train Loss: 0.0410 Accuracy: 0.9840
# val Loss: 0.1656 Accuracy: 0.9048
# Epoch: 63 / 200
# --------------------------
# train Loss: 0.0232 Accuracy: 0.9947
# val Loss: 0.0060 Accuracy: 1.0000
# Epoch: 64 / 200
# --------------------------
# train Loss: 0.0740 Accuracy: 0.9840
# val Loss: 0.0365 Accuracy: 0.9841
# Epoch: 65 / 200
# --------------------------
# train Loss: 0.0598 Accuracy: 0.9786
# val Loss: 0.0135 Accuracy: 1.0000
# Epoch: 66 / 200
# --------------------------
# train Loss: 0.0223 Accuracy: 1.0000
# val Loss: 0.0052 Accuracy: 1.0000
# Epoch: 67 / 200
# --------------------------
# train Loss: 0.0254 Accuracy: 0.9893
# val Loss: 0.0066 Accuracy: 1.0000
# Epoch: 68 / 200
# --------------------------
# train Loss: 0.0378 Accuracy: 0.9893
# val Loss: 0.0163 Accuracy: 1.0000
# Epoch: 69 / 200
# --------------------------
# train Loss: 0.0189 Accuracy: 0.9947
# val Loss: 0.0046 Accuracy: 1.0000
# Epoch: 70 / 200
# --------------------------
# train Loss: 0.0507 Accuracy: 0.9840
# val Loss: 0.0201 Accuracy: 1.0000
# Epoch: 71 / 200
# --------------------------
# train Loss: 0.0062 Accuracy: 1.0000
# val Loss: 0.0047 Accuracy: 1.0000
# Epoch: 72 / 200
# --------------------------
# train Loss: 0.0065 Accuracy: 1.0000
# val Loss: 0.0032 Accuracy: 1.0000
# Epoch: 73 / 200
# --------------------------
# train Loss: 0.0491 Accuracy: 0.9786
# val Loss: 0.0030 Accuracy: 1.0000
# Epoch: 74 / 200
# --------------------------
# train Loss: 0.0298 Accuracy: 0.9947
# val Loss: 0.0342 Accuracy: 1.0000
# Epoch: 75 / 200
# --------------------------
# train Loss: 0.0282 Accuracy: 0.9947
# val Loss: 0.0515 Accuracy: 0.9841
# Epoch: 76 / 200
# --------------------------
# train Loss: 0.0058 Accuracy: 1.0000
# val Loss: 0.0031 Accuracy: 1.0000
# Epoch: 77 / 200
# --------------------------
# train Loss: 0.0040 Accuracy: 1.0000
# val Loss: 0.0025 Accuracy: 1.0000
# Epoch: 78 / 200
# --------------------------
# train Loss: 0.0089 Accuracy: 0.9947
# val Loss: 0.0141 Accuracy: 1.0000
# Epoch: 79 / 200
# --------------------------
# train Loss: 0.0063 Accuracy: 1.0000
# val Loss: 0.0090 Accuracy: 1.0000
# Epoch: 80 / 200
# --------------------------
# train Loss: 0.0243 Accuracy: 0.9947
# val Loss: 0.0610 Accuracy: 0.9683
# Epoch: 81 / 200
# --------------------------
# train Loss: 0.0295 Accuracy: 0.9893
# val Loss: 0.0062 Accuracy: 1.0000
# Epoch: 82 / 200
# --------------------------
# train Loss: 0.0383 Accuracy: 0.9786
# val Loss: 0.0058 Accuracy: 1.0000
# Epoch: 83 / 200
# --------------------------
# train Loss: 0.0339 Accuracy: 0.9840
# val Loss: 0.0663 Accuracy: 0.9841
# Epoch: 84 / 200
# --------------------------
# train Loss: 0.0181 Accuracy: 0.9893
# val Loss: 0.0032 Accuracy: 1.0000
# Epoch: 85 / 200
# --------------------------
# train Loss: 0.0330 Accuracy: 0.9893
# val Loss: 0.0772 Accuracy: 0.9683
# Epoch: 86 / 200
# --------------------------
# train Loss: 0.0522 Accuracy: 0.9947
# val Loss: 0.0187 Accuracy: 1.0000
# Epoch: 87 / 200
# --------------------------
# train Loss: 0.0202 Accuracy: 0.9893
# val Loss: 0.0833 Accuracy: 0.9365
# Epoch: 88 / 200
# --------------------------
# train Loss: 0.0119 Accuracy: 0.9947
# val Loss: 0.0035 Accuracy: 1.0000
# Epoch: 89 / 200
# --------------------------
# train Loss: 0.0077 Accuracy: 0.9947
# val Loss: 0.0051 Accuracy: 1.0000
# Epoch: 90 / 200
# --------------------------
# train Loss: 0.0044 Accuracy: 1.0000
# val Loss: 0.0027 Accuracy: 1.0000
# Epoch: 91 / 200
# --------------------------
# train Loss: 0.0047 Accuracy: 1.0000
# val Loss: 0.0064 Accuracy: 1.0000
# Epoch: 92 / 200
# --------------------------
# train Loss: 0.0020 Accuracy: 1.0000
# val Loss: 0.0019 Accuracy: 1.0000
# Epoch: 93 / 200
# --------------------------
# train Loss: 0.0019 Accuracy: 1.0000
# val Loss: 0.0018 Accuracy: 1.0000
# Epoch: 94 / 200
# --------------------------
# train Loss: 0.0012 Accuracy: 1.0000
# val Loss: 0.0019 Accuracy: 1.0000
# Epoch: 95 / 200
# --------------------------
# train Loss: 0.0341 Accuracy: 0.9786
# val Loss: 0.0026 Accuracy: 1.0000
# Epoch: 96 / 200
# --------------------------
# train Loss: 0.0144 Accuracy: 0.9947
# val Loss: 0.0027 Accuracy: 1.0000
# Epoch: 97 / 200
# --------------------------
# train Loss: 0.0013 Accuracy: 1.0000
# val Loss: 0.0022 Accuracy: 1.0000
# Epoch: 98 / 200
# --------------------------
# train Loss: 0.0009 Accuracy: 1.0000
# val Loss: 0.0022 Accuracy: 1.0000
# Epoch: 99 / 200
# --------------------------
# train Loss: 0.0098 Accuracy: 1.0000
# val Loss: 0.0126 Accuracy: 1.0000
# Epoch: 100 / 200
# --------------------------
# train Loss: 0.0048 Accuracy: 1.0000
# val Loss: 0.0019 Accuracy: 1.0000
# Epoch: 101 / 200
# --------------------------
# train Loss: 0.0029 Accuracy: 1.0000
# val Loss: 0.0039 Accuracy: 1.0000
# Epoch: 102 / 200
# --------------------------
# train Loss: 0.0108 Accuracy: 1.0000
# val Loss: 0.0590 Accuracy: 0.9683
# Epoch: 103 / 200
# --------------------------
# train Loss: 0.0282 Accuracy: 0.9893
# val Loss: 0.0363 Accuracy: 1.0000
# Epoch: 104 / 200
# --------------------------
# train Loss: 0.0077 Accuracy: 1.0000
# val Loss: 0.0023 Accuracy: 1.0000
# Epoch: 105 / 200
# --------------------------
# train Loss: 0.0222 Accuracy: 0.9893
# val Loss: 0.0852 Accuracy: 0.9524
# Epoch: 106 / 200
# --------------------------
# train Loss: 0.0329 Accuracy: 0.9840
# val Loss: 0.0401 Accuracy: 1.0000
# Epoch: 107 / 200
# --------------------------
# train Loss: 0.0126 Accuracy: 1.0000
# val Loss: 0.0015 Accuracy: 1.0000
# Epoch: 108 / 200
# --------------------------
# train Loss: 0.0034 Accuracy: 1.0000
# val Loss: 0.0044 Accuracy: 1.0000
# Epoch: 109 / 200
# --------------------------
# train Loss: 0.0012 Accuracy: 1.0000
# val Loss: 0.0033 Accuracy: 1.0000
# Epoch: 110 / 200
# --------------------------
# train Loss: 0.0052 Accuracy: 1.0000
# val Loss: 0.0069 Accuracy: 1.0000
# Epoch: 111 / 200
# --------------------------
# train Loss: 0.0077 Accuracy: 0.9947
# val Loss: 0.0026 Accuracy: 1.0000
# Epoch: 112 / 200
# --------------------------
# train Loss: 0.0074 Accuracy: 1.0000
# val Loss: 0.0181 Accuracy: 1.0000
# Epoch: 113 / 200
# --------------------------
# train Loss: 0.0023 Accuracy: 1.0000
# val Loss: 0.0033 Accuracy: 1.0000
# Epoch: 114 / 200
# --------------------------
# train Loss: 0.0017 Accuracy: 1.0000
# val Loss: 0.0029 Accuracy: 1.0000
# Epoch: 115 / 200
# --------------------------
# train Loss: 0.0149 Accuracy: 0.9947
# val Loss: 0.0033 Accuracy: 1.0000
# Epoch: 116 / 200
# --------------------------
# train Loss: 0.0047 Accuracy: 1.0000
# val Loss: 0.0161 Accuracy: 1.0000
# Epoch: 117 / 200
# --------------------------
# train Loss: 0.0055 Accuracy: 1.0000
# val Loss: 0.0139 Accuracy: 1.0000
# Epoch: 118 / 200
# --------------------------
# train Loss: 0.0013 Accuracy: 1.0000
# val Loss: 0.0038 Accuracy: 1.0000
# Epoch: 119 / 200
# --------------------------
# train Loss: 0.0007 Accuracy: 1.0000
# val Loss: 0.0041 Accuracy: 1.0000
# Epoch: 120 / 200
# --------------------------
# train Loss: 0.0170 Accuracy: 0.9947
# val Loss: 0.0193 Accuracy: 1.0000
# Epoch: 121 / 200
# --------------------------
# train Loss: 0.0082 Accuracy: 0.9947
# val Loss: 0.0012 Accuracy: 1.0000
# Epoch: 122 / 200
# --------------------------
# train Loss: 0.0082 Accuracy: 1.0000
# val Loss: 0.0121 Accuracy: 1.0000
# Epoch: 123 / 200
# --------------------------
# train Loss: 0.0068 Accuracy: 1.0000
# val Loss: 0.0212 Accuracy: 1.0000
# Epoch: 124 / 200
# --------------------------
# train Loss: 0.0020 Accuracy: 1.0000
# val Loss: 0.0023 Accuracy: 1.0000
# Epoch: 125 / 200
# --------------------------
# train Loss: 0.0006 Accuracy: 1.0000
# val Loss: 0.0020 Accuracy: 1.0000
# Epoch: 126 / 200
# --------------------------
# train Loss: 0.0030 Accuracy: 1.0000
# val Loss: 0.0050 Accuracy: 1.0000
# Epoch: 127 / 200
# --------------------------
# train Loss: 0.0011 Accuracy: 1.0000
# val Loss: 0.0025 Accuracy: 1.0000
# Epoch: 128 / 200
# --------------------------
# train Loss: 0.0008 Accuracy: 1.0000
# val Loss: 0.0013 Accuracy: 1.0000
# Epoch: 129 / 200
# --------------------------
# train Loss: 0.0019 Accuracy: 1.0000
# val Loss: 0.0031 Accuracy: 1.0000
# Epoch: 130 / 200
# --------------------------
# train Loss: 0.0059 Accuracy: 1.0000
# val Loss: 0.0064 Accuracy: 1.0000
# Epoch: 131 / 200
# --------------------------
# train Loss: 0.0014 Accuracy: 1.0000
# val Loss: 0.0023 Accuracy: 1.0000
# Epoch: 132 / 200
# --------------------------
# train Loss: 0.0008 Accuracy: 1.0000
# val Loss: 0.0021 Accuracy: 1.0000
# Epoch: 133 / 200
# --------------------------
# train Loss: 0.0031 Accuracy: 1.0000
# val Loss: 0.0021 Accuracy: 1.0000
# Epoch: 134 / 200
# --------------------------
# train Loss: 0.0010 Accuracy: 1.0000
# val Loss: 0.0008 Accuracy: 1.0000
# Epoch: 135 / 200
# --------------------------
# train Loss: 0.0007 Accuracy: 1.0000
# val Loss: 0.0005 Accuracy: 1.0000
# Epoch: 136 / 200
# --------------------------
# train Loss: 0.0121 Accuracy: 0.9947
# val Loss: 0.0364 Accuracy: 0.9841
# Epoch: 137 / 200
# --------------------------
# train Loss: 0.0018 Accuracy: 1.0000
# val Loss: 0.0014 Accuracy: 1.0000
# Epoch: 138 / 200
# --------------------------
# train Loss: 0.0009 Accuracy: 1.0000
# val Loss: 0.0016 Accuracy: 1.0000
# Epoch: 139 / 200
# --------------------------
# train Loss: 0.0008 Accuracy: 1.0000
# val Loss: 0.0014 Accuracy: 1.0000
# Epoch: 140 / 200
# --------------------------
# train Loss: 0.0012 Accuracy: 1.0000
# val Loss: 0.0007 Accuracy: 1.0000
# Epoch: 141 / 200
# --------------------------
# train Loss: 0.0008 Accuracy: 1.0000
# val Loss: 0.0005 Accuracy: 1.0000
# Epoch: 142 / 200
# --------------------------
# train Loss: 0.0006 Accuracy: 1.0000
# val Loss: 0.0006 Accuracy: 1.0000
# Epoch: 143 / 200
# --------------------------
# train Loss: 0.0005 Accuracy: 1.0000
# val Loss: 0.0008 Accuracy: 1.0000
# Epoch: 144 / 200
# --------------------------
# train Loss: 0.0003 Accuracy: 1.0000
# val Loss: 0.0007 Accuracy: 1.0000
# Epoch: 145 / 200
# --------------------------
# train Loss: 0.0006 Accuracy: 1.0000
# val Loss: 0.0005 Accuracy: 1.0000
# Epoch: 146 / 200
# --------------------------
# train Loss: 0.0186 Accuracy: 0.9947
# val Loss: 0.0030 Accuracy: 1.0000
# Epoch: 147 / 200
# --------------------------
# train Loss: 0.0043 Accuracy: 1.0000
# val Loss: 0.0011 Accuracy: 1.0000
# Epoch: 148 / 200
# --------------------------
# train Loss: 0.0057 Accuracy: 0.9947
# val Loss: 0.0005 Accuracy: 1.0000
# Epoch: 149 / 200
# --------------------------
# train Loss: 0.0020 Accuracy: 1.0000
# val Loss: 0.0271 Accuracy: 0.9841
# Epoch: 150 / 200
# --------------------------
# train Loss: 0.0008 Accuracy: 1.0000
# val Loss: 0.0082 Accuracy: 1.0000
# Epoch: 151 / 200
# --------------------------
# train Loss: 0.0054 Accuracy: 1.0000
# val Loss: 0.0015 Accuracy: 1.0000
# Epoch: 152 / 200
# --------------------------
# train Loss: 0.0014 Accuracy: 1.0000
# val Loss: 0.0012 Accuracy: 1.0000
# Epoch: 153 / 200
# --------------------------
# train Loss: 0.0005 Accuracy: 1.0000
# val Loss: 0.0005 Accuracy: 1.0000
# Epoch: 154 / 200
# --------------------------
# train Loss: 0.0004 Accuracy: 1.0000
# val Loss: 0.0005 Accuracy: 1.0000
# Epoch: 155 / 200
# --------------------------
# train Loss: 0.0015 Accuracy: 1.0000
# val Loss: 0.0014 Accuracy: 1.0000
# Epoch: 156 / 200
# --------------------------
# train Loss: 0.0074 Accuracy: 1.0000
# val Loss: 0.0001 Accuracy: 1.0000
# Epoch: 157 / 200
# --------------------------
# train Loss: 0.0072 Accuracy: 0.9947
# val Loss: 0.0005 Accuracy: 1.0000
# Epoch: 158 / 200
# --------------------------
# train Loss: 0.0068 Accuracy: 1.0000
# val Loss: 0.0002 Accuracy: 1.0000
# Epoch: 159 / 200
# --------------------------
# train Loss: 0.0016 Accuracy: 1.0000
# val Loss: 0.0006 Accuracy: 1.0000
# Epoch: 160 / 200
# --------------------------
# train Loss: 0.0049 Accuracy: 1.0000
# val Loss: 0.0067 Accuracy: 1.0000
# Epoch: 161 / 200
# --------------------------
# train Loss: 0.0005 Accuracy: 1.0000
# val Loss: 0.0002 Accuracy: 1.0000
# Epoch: 162 / 200
# --------------------------
# train Loss: 0.0020 Accuracy: 1.0000
# val Loss: 0.0026 Accuracy: 1.0000
# Epoch: 163 / 200
# --------------------------
# train Loss: 0.0055 Accuracy: 1.0000
# val Loss: 0.0002 Accuracy: 1.0000
# Epoch: 164 / 200
# --------------------------
# train Loss: 0.0003 Accuracy: 1.0000
# val Loss: 0.0009 Accuracy: 1.0000
# Epoch: 165 / 200
# --------------------------
# train Loss: 0.0088 Accuracy: 0.9947
# val Loss: 0.0013 Accuracy: 1.0000
# Epoch: 166 / 200
# --------------------------
# train Loss: 0.0006 Accuracy: 1.0000
# val Loss: 0.0003 Accuracy: 1.0000
# Epoch: 167 / 200
# --------------------------
# train Loss: 0.0061 Accuracy: 1.0000
# val Loss: 0.0026 Accuracy: 1.0000
# Epoch: 168 / 200
# --------------------------
# train Loss: 0.0009 Accuracy: 1.0000
# val Loss: 0.0024 Accuracy: 1.0000
# Epoch: 169 / 200
# --------------------------
# train Loss: 0.0006 Accuracy: 1.0000
# val Loss: 0.0007 Accuracy: 1.0000
# Epoch: 170 / 200
# --------------------------
# train Loss: 0.0011 Accuracy: 1.0000
# val Loss: 0.0010 Accuracy: 1.0000
# Epoch: 171 / 200
# --------------------------
# train Loss: 0.0008 Accuracy: 1.0000
# val Loss: 0.0011 Accuracy: 1.0000
# Epoch: 172 / 200
# --------------------------
# train Loss: 0.0005 Accuracy: 1.0000
# val Loss: 0.0013 Accuracy: 1.0000
# Epoch: 173 / 200
# --------------------------
# train Loss: 0.0004 Accuracy: 1.0000
# val Loss: 0.0192 Accuracy: 0.9841
# Epoch: 174 / 200
# --------------------------
# train Loss: 0.0002 Accuracy: 1.0000
# val Loss: 0.0121 Accuracy: 1.0000
# Epoch: 175 / 200
# --------------------------
# train Loss: 0.0003 Accuracy: 1.0000
# val Loss: 0.0047 Accuracy: 1.0000
# Epoch: 176 / 200
# --------------------------
# train Loss: 0.0001 Accuracy: 1.0000
# val Loss: 0.0039 Accuracy: 1.0000
# Epoch: 177 / 200
# --------------------------
# train Loss: 0.0007 Accuracy: 1.0000
# val Loss: 0.0005 Accuracy: 1.0000
# Epoch: 178 / 200
# --------------------------
# train Loss: 0.0010 Accuracy: 1.0000
# val Loss: 0.0008 Accuracy: 1.0000
# Epoch: 179 / 200
# --------------------------
# train Loss: 0.0002 Accuracy: 1.0000
# val Loss: 0.0148 Accuracy: 1.0000
# Epoch: 180 / 200
# --------------------------
# train Loss: 0.0003 Accuracy: 1.0000
# val Loss: 0.0046 Accuracy: 1.0000
# Epoch: 181 / 200
# --------------------------
# train Loss: 0.0001 Accuracy: 1.0000
# val Loss: 0.0032 Accuracy: 1.0000
# Epoch: 182 / 200
# --------------------------
# train Loss: 0.0000 Accuracy: 1.0000
# val Loss: 0.0028 Accuracy: 1.0000
# Epoch: 183 / 200
# --------------------------
# train Loss: 0.0002 Accuracy: 1.0000
# val Loss: 0.0021 Accuracy: 1.0000
# Epoch: 184 / 200
# --------------------------
# train Loss: 0.0001 Accuracy: 1.0000
# val Loss: 0.0014 Accuracy: 1.0000
# Epoch: 185 / 200
# --------------------------
# train Loss: 0.0004 Accuracy: 1.0000
# val Loss: 0.0021 Accuracy: 1.0000
# Epoch: 186 / 200
# --------------------------
# train Loss: 0.0001 Accuracy: 1.0000
# val Loss: 0.0016 Accuracy: 1.0000
# Epoch: 187 / 200
# --------------------------
# train Loss: 0.0002 Accuracy: 1.0000
# val Loss: 0.0024 Accuracy: 1.0000
# Epoch: 188 / 200
# --------------------------
# train Loss: 0.0002 Accuracy: 1.0000
# val Loss: 0.0032 Accuracy: 1.0000
# Epoch: 189 / 200
# --------------------------
# train Loss: 0.0003 Accuracy: 1.0000
# val Loss: 0.0011 Accuracy: 1.0000
# Epoch: 190 / 200
# --------------------------
# train Loss: 0.0026 Accuracy: 1.0000
# val Loss: 0.0341 Accuracy: 0.9841
# Epoch: 191 / 200
# --------------------------
# train Loss: 0.0006 Accuracy: 1.0000
# val Loss: 0.0017 Accuracy: 1.0000
# Epoch: 192 / 200
# --------------------------
# train Loss: 0.0001 Accuracy: 1.0000
# val Loss: 0.0028 Accuracy: 1.0000
# Epoch: 193 / 200
# --------------------------
# train Loss: 0.0000 Accuracy: 1.0000
# val Loss: 0.0022 Accuracy: 1.0000
# Epoch: 194 / 200
# --------------------------
# train Loss: 0.0000 Accuracy: 1.0000
# val Loss: 0.0019 Accuracy: 1.0000
# Epoch: 195 / 200
# --------------------------
# train Loss: 0.0010 Accuracy: 1.0000
# val Loss: 0.0165 Accuracy: 1.0000
# Epoch: 196 / 200
# --------------------------
# train Loss: 0.0008 Accuracy: 1.0000
# val Loss: 0.0034 Accuracy: 1.0000
# Epoch: 197 / 200
# --------------------------
# train Loss: 0.0001 Accuracy: 1.0000
# val Loss: 0.0014 Accuracy: 1.0000
# Epoch: 198 / 200
# --------------------------
# train Loss: 0.0001 Accuracy: 1.0000
# val Loss: 0.0013 Accuracy: 1.0000
# Epoch: 199 / 200
# --------------------------
# train Loss: 0.0001 Accuracy: 1.0000
# val Loss: 0.0019 Accuracy: 1.0000
# Epoch: 200 / 200
# --------------------------
# train Loss: 0.0240 Accuracy: 0.9893
# val Loss: 0.0194 Accuracy: 1.0000
